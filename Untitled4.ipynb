# %% [markdown]
# <a href="https://colab.research.google.com/github/carolinaortiz3153-wq/programacion1/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nombre: Jenny Carolina Suarez Ortiz

# %% [markdown]
# PARTE II

# %% [markdown]
# INSTRUCCIÓN I

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

# %%
A.difference(B)
# Out:
# {1, 2}

# %% [markdown]
# El metodo difference imprime un conjunto de los elementos de A que no están en B.

# %%
symmetric_difference = A.symmetric_difference(B)
print(symmetric_difference)
# Out:
# {1, 2, 5, 6}

# %% [markdown]
# El metodo symmetric_difference imprime un conjunto con los elementos no compartidos entre A y B.

# %% [markdown]
# INSTRUCCIÓN II

# %%
a = {1, 2, 3, 4, 5}
b = {1, 2, 3}

# %%
A.issuperset(B)
# Out:
# False

# %% [markdown]
# El metodo issuperset verifica si todos los elementos del conjunto a están en el conjunto b por lo que el valor devuelto es False porque no todos los elementos de a están en b.

# %%
a.isdisjoint(b)
# Out:
# False

# %% [markdown]
# El metodo isdisjoint verifica si

# %% [markdown]
# INSTRUCCIÓN III

# %%
datos2 = {
    "vino tinto": "si",
    "vino blanco": "no"
}

# %%
datos2.update({"vino rosado": "puede ser"})
print(datos2)
# Out:
# {'vino tinto': 'si', 'vino blanco': 'no', 'vino rosado': 'puede ser'}

# %%
datos2.update({"vino tinto": "si"})
print(datos2)
# Out:
# {'vino tinto': 'si', 'vino blanco': 'no'}

# %% [markdown]
# El metodo update agrega la clave y el valor del nuevo diccionario al diccionario inicial si no es una clave-valor repetida, si la clave-valor es repetida no se modifica el diccionario inicial.

# %% [markdown]
# INSTRUCCIÓN IV

# %%
datos3 = {
    "clase en la mañana": "no",
    "clase en la tarde": "si",
}

# %%
datos3.setdefault("clase en la noche", "nunca")
# Out:
# 'nunca'

# %%
datos3.setdefault("clase en la noche", "no")
# Out:
# 'no'

# %%
datos3.setdefault("clase en la tarde", "si")
# Out:
# 'si'

# %% [markdown]
# El metodo setdefault imprime el valor correspondiente a la clave sin importar si se introduce un valor que no corresponde a la clave o si el valor se repite.

# %% [markdown]
# PARTE III

# %% [markdown]
# CODIGO I

# %%
m = 5
if isinstance(m, int) and m >= 0:
  for n in range(0, (m+1)):
    if n == 1 or n == 0:
      print("El número es ", n)
    else:
      for x in range(1, n):
        if m == 6 * x + 1 :
          print(n, 'es primo')
      else:
        print(n, "no es primo")
else:
 print("El número no es natural")
 #no funcionó :(
# Out:
# El número es  0
# El número es  1
# 2 no es primo
# 3 no es primo
# 4 no es primo
# 5 no es primo

# %% [markdown]
# CODIGO II

# %%
def contador_vocales1(palabra):
  vocales = "aeiou"
  consonantes = "bcdfghjklmnñpqrstvwxyz"
  contador = 0
  contador1 = 0
  contador2 = 0

  for letra in palabra.lower():
    if letra in vocales:
      contador += 1
    elif letra in consonantes:
      contador1 += 1
    else:
      contador2 += 1
  return({"Cantidad de vocales:": contador,
          "Cantidad de consonates:": contador1,
          "Cantidad de otros caracteres:": contador2})
