# %% [markdown]
# <a href="https://colab.research.google.com/github/carolinaortiz3153-wq/programacion1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def saludar():
    "la funcion que te saluda"
    print("hola mundo")

# %%
saludar()
# Out:
# hola mundo

# %%
saludar
# Out:
# <function __main__.saludar()>

# %%
def sumar(a, b):
    return a + b

# %%
resultado = sumar (a =3, b= 5)
resultado
# Out:
# 8

# %%
def saludar(nombre="estudiante"):
    print("hola", nombre)
saludar()
saludar(nombre = "carolina")
# Out:
# hola estudiante
# hola carolina

# %%
def operaciones(a, b):
  suma = a + b
  resta = a - b
  return suma, resta
s, r = operaciones(b= 10, a = 5)
print(s, r)
# Out:
# 15 -5

# %%
def operaciones(a, b):
  multiplicacion = a * b
  dividion = a / b
  return multiplicacion, dividion
s, r = operaciones (b = 17, a = 3)
print(s, r)
# Out:
# 51 0.17647058823529413
