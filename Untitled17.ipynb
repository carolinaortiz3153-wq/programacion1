# %% [markdown]
# <a href="https://colab.research.google.com/github/carolinaortiz3153-wq/programacion1/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
usuarios = {
    "ANA": "1234",
    "JUAN": "abcd"
}

try:
    usuario = input("Usuario: ").upper()
    password = input("Contraseña: ")

    if usuario not in usuarios:
        raise KeyError("El usuario no existe")

    if usuarios[usuario] != password:
        raise ValueError("Contraseña incorrecta")

    else:
        print("Bienvenido,", usuario)

except KeyError as e:
    print("Error:", e)

except ValueError as e:
    print("Error:", e)
# Out:
# Usuario: ANA
# Contraseña: 1234
# Bienvenido, ANA

# %%
try:
    usuario = input("Usuario: ").upper()

    if usuario not in usuarios:
        raise KeyError("El usuario no existe")

    elif usuarios[usuario] != input("Contraseña: "):
      raise ValueError("Contraseña incorrecta")

    else:
        print("Bienvenido,", usuario)

except KeyError as e:
    print("Error:", e)

except ValueError as e:
    print("Error:", e)
# Out:
# Usuario: hola
# Error: 'El usuario no existe'

# %% [markdown]
# el primer codigo usa datos para la autentificacion

# %%
try:
    num1 = float(input("numero 1: "))
    num2 = float(input("numero 2: "))
    op = input("operacion (+, -, *, /): ")

    if op == "+":
      resultado = num1 + num2
    elif op == "-":
      resultado = num1 - num2
    elif op == "*":
      resultado = num1 * num2
    elif op == "/":
      resultado = num1 / num2
    else:
      raise ValueError("operacion no valida")
    print("resultado", resultado)
except TypeError as e:
    print("Error de tipo: ", e)
# Out:
# numero 1: 8
# numero 2: 2
# operacion (+. -, *, /): +
# resultado 10.0

# %%
try:
    num1 = (input("numero 1: "))
    num2 = (input("numero 2: "))
    op = input("operacion (+. -, *, /): ")

    if op == "+":
      resultado = num1 + num2
    elif op == "-":
      resultado = num1 - num2
    elif op == "*":
      resultado = num1 * num2
    elif op == "/":
      resultado = num1 / num2
    else:
      raise ValueError("operacion no valida")
    print("resultado", resultado)
except TypeError as e:
    print("Error de tipo: ", e)
# Out:
# numero 1: a
# numero 2: 0
# operacion (+. -, *, /): /
# Error de tipo:  unsupported operand type(s) for /: 'str' and 'str'

# %%
try:
    num1 = float(input("numero 1: "))
except ValueError:
    print("Error: el primer valor ingresado no es un numero valido")
    exit()

try:
    num2 = float(input("numero 2: "))
    op = input("operacion (+, -, *, /): ")

    if op == "+":
        resultado = num1 + num2
    elif op == "-":
        resultado = num1 - num2
    elif op == "*":
        resultado = num1 * num2
    elif op == "/":
        resultado = num1 / num2
    else:
        raise ValueError("operacion no valida")

    print("resultado:", resultado)

except ValueError as e:
    print("Error:", e)
except ZeroDivisionError:
    print("Error: no se puede dividir entre cero")
except IndexError:
    print("Error: indice fuera de rango")
except TypeError:
    print("Error: tipos de datos no compatibles")
except Exception as e:
    print("Error:", e)
# Out:
# numero 1: l
# Error: el primer valor ingresado no es un numero valido
# numero 2: a
# Error: could not convert string to float: 'a'

# %%
try:
    datos = input("Ingresa números separados por coma: ")
    lista = [float(x) for x in datos.split(",")]

    indice = int(input("Índice a consultar: "))
    print("Elemento:", lista[indice])

except ValueError:
    print("Debes ingresar solo números")

except IndexError:
    print("El índice está fuera de rango")

except IndexError:
    print("Error: indice fuera de rango")

except TypeError:
    print("Error: tipos de datos no compatibles")

except Exception as e:
    print("Error:", e)
