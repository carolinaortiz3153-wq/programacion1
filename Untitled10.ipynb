# %% [markdown]
# <a href="https://colab.research.google.com/github/carolinaortiz3153-wq/programacion1/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile pedirnotas.py
def pedir_nombre():
  return input("ingrese el nombre del estudiante: ")

def pedir_notas():
  n1 = float(input("nota 1: "))
  n2 = float(input("nota 2: "))
  n3 = float(input("nota 3: "))
  return [n1, n2, n3]
# Out:
# Overwriting pedirnotas.py

# %%
# %%writefile promedio.py
def calcular_promedio(n1, n2, n3):
  return (n1 + n2 + n3) / 3
# Out:
# Overwriting promedio.py

# %%
import pedirnotas
nombre = pedirnotas.pedir_nombre()
# Out:
# ingrese el nombre del estudiante: carolina

# %%
import importlib
import pedirnotas
importlib.reload(pedirnotas)
notas = pedirnotas.pedir_notas()
# Out:
# nota 1: 2
# nota 2: 2
# nota 3: 3

# %%
# %%writefile calculos.py

def suma(a, b):
    return a + b
def multiplicar(a, b):
    return a * b
# Out:
# Overwriting calculos.py

# %%
# %%writefile calculos.py
import statistics
def calcular_promedio(n1, n2, n3):
  return (n1 + n2 + n3) / 3

def mediana(n1, n2 , n3):
   return statistics.mediana([n1, n2, n3])
# Out:
# Overwriting calculos.py

# %%
import os
os.makedirs("src", exist_ok=True)

# %%
# %%writefile src/operaciones.py

def dividir(a, b):
  return a / b
# Out:
# Writing src/operaciones.py

# %%
from src.operaciones import dividir
print(dividir(10, 2))
# Out:
# 5.0
