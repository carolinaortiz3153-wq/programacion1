# %% [markdown]
# <a href="https://colab.research.google.com/github/carolinaortiz3153-wq/programacion1/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 10 / 0

# %%
try:
   x = int(input("introduce un numero: "))
   print(10 / x)
except:
  pritn("ocurrió un error")

# %%
try:
  x = int(input("introduzca un numero: "))
  print(10/x)

# %%
try:
   lista = [1, 2, 3, 4, 5]
   print(lista[9])
except (IndexError, TypeError) as e:
  print(f"ocurrió un error: {e}")

# %%
lista = [1, 2, 3, 4, 5]
try:
 x = int(input("introduzca un numero: "))
  print(lista[x])
except (IndexError, TypeError, ValueError) as e:
  print(f"ocurrió un error: {e}")

# %%
try:
   x = int(input("numero: "))
   print("todo salió bien.", x)
except ValueError:
   print("error en la conversion")
finally:
   print("este bloque siempre se ejecuta")

# %%
try:
   edad = int(input("edad: "))
   if edad > 0:
       raise ValueError("la edad no puede ser negativa")
     print("edad valida", edad)
except ValueError as e:
   print("error:" e)

# %%
int("abc")

# %%
try:
    dato = input("ingresa un numero: ")
    numero = float(dato)
    print("numero:", numero)
except ValueError as e:
    print("ValueError:", e)

# %%
try:
    dato = input("ingresa un numero complejo: ")
    numero = complex(dato)
    print("numero complejo:", numero)
except ValueError as e:
    print("ValueError:", e)

# %%
try:
    texto = input("ingresa un texto: ")
    numero = int(input("ingrese un numero: "))
    resultado = texto + numero
    print(resultado)
except TypeError as e:
    print("TypeError:", e)
except ValueError as e:
    print("ValueError:", e)

# %%
try:
   lista = input("ingrese los elementos separados por coma: ").split("2")
   indice = int(input("ingrese una posicion: "))
   print("elemento:", lista[indice])
except IndexError as e:
   print("IndexError:", e)
except ValueError as e:
    print("ValueError:", e)

# %%
try:
   dic = {"a": 1, "b": 2}
   clave = int(input("ingrese la clave (a/b): "))
   print("valor:", dic[clave])
except (KeyError, ValueError) as e:
   print("el usuario definido no existe")

# %%
carro = 4
try:
    nombre_variable = input("escribe el lnombre de la variable: ")
    print(nombre_variable)
except NameError as e.
     print("NameError:", e)

# %%
try:
   a = float(input("numero 1: "))
   b = float(input("numero 2: "))
   print("resultado: ", a /b)
except ZeroDivisionError as e:
print("al dividir entre zero se obtiene una indeterminacion")

# %%
try:
   a = int(input("numero 1: "))
   b = input("cadena: ")
   print("producto: ", a * b)
except ValueError.
  print("no se puede multiplicar por una cadena")

# %%
open("archivo_inexistence.txt")
