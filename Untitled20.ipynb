# %% [markdown]
# <a href="https://colab.research.google.com/github/carolinaortiz3153-wq/programacion1/blob/main/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# JENNY CAROLINA SUAREZ ORTIZ

# %% [markdown]
# PARTE II

# %% [markdown]
# INSTRUCCION I

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(0)
datos = np.random.randint(1, 198, 50)
datos
# Out:
# array([13, 16,  1,  4,  4,  8, 10,  5,  7, 13,  2,  7,  8, 15, 18,  6, 14,
#         9, 10, 17,  6, 16, 16,  1,  4, 18, 15,  8,  1,  2, 10,  1, 11,  4,
#        12,  3,  1,  1,  5,  6,  7,  9, 18, 16,  5, 10, 11,  2,  2,  8])

# %% [markdown]
# INSTRUCCION II

# %%
df = pd.DataFrame({
                   "nombre": ["daniel ", "alejandra", "luis", "santiago", "diana"],
                   "genero": ["masculino ", "femenino", "masculino", "masculino", "femenino"],
                   "semestre": [2, 7, 6, 9, 13],
                   "traguitos": [12, 27, 22, 40, 64]
})
df
# Out:
#       nombre      genero  semestre  traguitos
# 0    daniel   masculino          2         12
# 1  alejandra    femenino         7         27
# 2       luis   masculino         6         22
# 3   santiago   masculino         9         40
# 4      diana    femenino        13         64

# %%
df.head(2)
# Out:
#       nombre      genero  semestre  traguitos
# 0    daniel   masculino          2         12
# 1  alejandra    femenino         7         27

# %%
df["nombre"]
# Out:
# 0      daniel
# 1    alejandra
# 2         luis
# 3     santiago
# 4        diana
# Name: nombre, dtype: object

# %%
a = df.loc[0]
a
# Out:
# nombre          daniel
# genero       masculino
# semestre              2
# traguitos            12
# Name: 0, dtype: object

# %%
b = df.loc[1]
b
# Out:
# nombre       alejandra
# genero        femenino
# semestre             7
# traguitos           27
# Name: 1, dtype: object

# %% [markdown]
# # CREAR UN CSV:
# from google.colab import files
# import csv
# datos = [
#     ["Nombre", "Edad", "Ciudad"],
#     ["Ana", 25, "Bogotá"],
#     ["Luis", 30, "Medellín"],
#     ["Carlos", 28, "Cali"]
# ]
#
# with open("datos.csv", "w", newline="") as f:
#     writer = csv.writer(f)
#     writer.writerows(datos)
#
# files.download("datos.csv")
#
# # CREAR MODULOS Y PAQUETES:
#
# import os
# os.makedirs("op", exist_ok=True)
#
# %%writefile op/operaciones.py
#
# # FUNCION LAMBDA
# import pandas as pd
# x = [1, 2, 3, 4]
# x = pd.DataFrame(x)
# normalizar = lambda x: (x - x.mean()) / x.std()
# resultado = normalizar(x)
# print(resultado)

# %% [markdown]
# PROYECTO

# %%
import numpy as np
import pandas as pd

np.random.seed(123)

# %%
datos = np.random.normal(loc=7.2, scale=0.4, size=53)
df = pd.DataFrame({
    "evaluaciones" : datos
})
datos
# Out:
# array([7.27015461, 7.01499778, 6.76567976, 7.4558944 , 7.04565467,
#        6.88969506, 7.59828454, 6.42671809, 7.29941225, 7.18750187,
#        7.14421042, 7.12373761, 7.37945501, 6.80302809, 7.10962414,
#        6.53817169, 6.94411094, 7.00823208, 7.3245454 , 6.88959181,
#        7.07705408, 7.05339042, 7.64788478, 7.01683103, 7.37015736,
#        7.18881153, 7.79039593, 7.45871204, 7.05426628, 6.92848904,
#        7.05854886, 6.90370101, 6.92999127, 7.1468863 , 7.44792043,
#        7.91646738, 7.26840018, 6.50973146, 7.26426342, 6.85640587,
#        7.11743162, 7.39537059, 6.86466761, 7.3524655 , 6.80363869,
#        7.60715202, 7.33663496, 6.69964551, 7.5701003 , 6.83808554,
#        7.93747661, 7.8102029 , 6.62178577])

# %%
df.describe()
# Out:
#        evaluaciones
# count     53.000000
# mean       7.152107
# std        0.350288
# min        6.426718
# 25%        6.903701
# 50%        7.117432
# 75%        7.370157
# max        7.937477

# %%
from scipy.stats import shapiro
shapiro(df["evaluaciones"])
# Out:
# ShapiroResult(statistic=np.float64(0.9848841585264719), pvalue=np.float64(0.7362327044063028))

# %% [markdown]
# se aceptan que las evaluacioes sean iguales para ambos grupos con una confianza del 95% ya que el valor p es mayor a 0.05
