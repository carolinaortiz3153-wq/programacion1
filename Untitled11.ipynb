# %% [markdown]
# <a href="https://colab.research.google.com/github/carolinaortiz3153-wq/programacion1/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile pedirnotas.py
def pedir_nombre():
  return input("ingrese el nombre del estudiante: ")

def pedir_notas():
  n1 = float(input("nota 1: "))
  n2 = float(input("nota 2: "))
  n3 = float(input("nota 3: "))
  n4 = float(input("nota 4: "))
  return [n1, n2, n3, n4]
# Out:
# Writing pedirnotas.py

# %%
# %%writefile promedio.py
def calcular_promedio(n1, n2, n3, n4):
  return (n1 + n2 + n3 + n4) / 4
# Out:
# Writing promedio.py

# %%
import pedirnotas
nombre = pedirnotas.pedir_nombre()
# Out:
# ingrese el nombre del estudiante: carolina

# %%
import importlib
import pedirnotas
importlib.reload(pedirnotas)
notas = pedirnotas.pedir_notas()
# Out:
# nota 1: 2
# nota 2: 2
# nota 3: 3.5
# nota 4: 2.7

# %%
# %%writefile calculos.py
import statistics
def calcular_mediana(n1, n2, n3, n4):
  return (n2 + n3) / 2

def mediana(n1, n2 , n3, n4):
   return statistics.mediana([n1, n2, n3, n4])
# Out:
# Overwriting calculos.py

# %%
# %%writefile calculos.py
import statistics
def calcular_moda(n1, n2, n3, n4):
   return statistics.mode()

def moda(n1, n2 , n3, n4):
   return statistics.moda([n1, n2, n3, n4])
# Out:
# Overwriting calculos.py

# %%
if calcular_promedio < 3.0
 print("reprobado")
else:
 print("aprobado")
