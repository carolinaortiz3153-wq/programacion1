# %% [markdown]
# <a href="https://colab.research.google.com/github/carolinaortiz3153-wq/programacion1/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

# %%
try:
    nombre = input("Ingrese su nombre y apellido sin espacios: ").lower()
    edad = input("Ingrese su edad: ")
    if not re.fullmatch(r"[a-zA-Z]+", nombre):
        raise ValueError("El nombre solo debe contener letras")
    if not re.fullmatch(r"\d+", edad):
        raise ValueError("La edad debe contener solo números")
    contrasena = nombre[:3] + edad + "@2026"
    print("Contraseña generada:")
    print(contrasena)
except ValueError as e:
    print("Error:", e)
# Out:
# Ingrese su nombre y apellido sin espacios: carolina
# Ingrese su edad: 18
# Contraseña generada:
# car18@2026

# %%
try:
    nombre = input("Ingrese su nombre y apellido sin espacios: ").lower()
    edad = input("Ingrese su edad: ")
    if not re.fullmatch(r"[a-zA-Z]+", nombre):
        raise ValueError("El nombre solo debe contener letras")
    if not re.fullmatch(r"\d+", edad):
        raise ValueError("La edad debe contener solo números")
    correo = nombre + edad + "@uis.edu.co"
    print("Correo generado:")
    print(correo)
except ValueError as e:
    print("Error:", e)
# Out:
# Ingrese su nombre y apellido sin espacios: carolinasuarez
# Ingrese su edad: 18
# Correo generado:
# carolinasuarez18@uis.edu.co

# %%
try:
    nombre = input("Ingrese su nombre sin espacios: ").lower()
    apellido = input("ingrese su apellido: ").lower
    CC = input("Ingrese su CC o TI: ")
    if not re.fullmatch(r"[a-zA-Z]+", nombre):
        raise ValueError("El nombre solo debe contener letras")
    if not re.fullmatch(r"\d+", edad):
        raise ValueError("La edad debe contener solo números")
    if not re.fullmatch(r"\d+", CC):
        raise ValueError("CC o TI invalido")
    correo = nombre + apellido + CC[:3] + "@uis.edu.co"
    print("Correo generado:")
    print(correo)
except ValueError as e:
    print("Error:", e)
# Out:
# Ingrese su nombre sin espacios: carolina
# ingrese su apellido: suarez
# Ingrese su CC o TI: 111
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4702/3963013289.py in <cell line: 0>()
#       9     if not re.fullmatch(r"\d+", CC):
#      10         raise ValueError("CC o TI invalido")
# ---> 11     correo = nombre + apellido + CC[:3] + "@uis.edu.co"
#      12     print("Correo generado:")
#      13     print(correo)
#
# TypeError: can only concatenate str (not "builtin_function_or_method") to str

# %%
try:
 nombre_completo = input("Ingrese su nombre completo: ").lower()
 # Validar que solo haya letras y espacios
 if not re.fullmatch(r"[a-zA-Záéíóúñ\s]+", nombre_completo):
    raise ValueError("Solo se permiten letras y espacios")
 partes = nombre_completo.split()
 # Validar mínimo nombre y apellido
 if len(partes) < 2:
    raise ValueError("Debe ingresar al menos nombre y apellido")
 # Caso: un nombre y un apellido
 if len(partes) == 2:
    primer_nombre = partes[0]
    primer_apellido = partes[1]
    correo = primer_nombre[0] + primer_apellido + "@gmail.com"
 # Caso: dos nombres y un apellido
 elif len(partes) == 3:
     primer_nombre = partes[0]
     primer_apellido = partes[1]
     segundo_apellido = partes[2]
     correo = (
        primer_nombre[0]
      + primer_apellido
      + segundo_apellido[0]
      + "@gmail.com"
 )
 # Caso: dos nombres y dos apellidos
 else:
     primer_nombre = partes[0]
     segundo_nombre = partes[1]
     primer_apellido = partes[2]
     segundo_apellido = partes[3]
     correo = (
        primer_nombre[0]
      + segundo_nombre[0]
      + primer_apellido
      + segundo_apellido[0]
      + "@gmail.com"
 )
 print("Correo generado:")
 print(correo)
except ValueError as e:
  print("Error:", e)
# Out:
# Ingrese su nombre completo: jenny carolina suarez ortiz
# Correo generado:
# jcsuarezo@gmail.com

# %%
try:
 nombre_completo = input("Ingrese su nombre completo: ").lower()
 # Validar que solo haya letras y espacios
 if not re.fullmatch(r"[a-zA-Záéíóúñ\s]+", nombre_completo):
    raise ValueError("Solo se permiten letras y espacios")
 partes = nombre_completo.split()
 # Validar mínimo nombre y apellido
 if len(partes) < 2:
    raise ValueError("Debe ingresar al menos nombre y apellido")
 # Caso: un nombre y un apellido
 if len(partes) == 2:
    primer_nombre = partes[0]
    primer_apellido = partes[1]
    correo = primer_nombre[0] + primer_apellido + "@gmail.com"
 # Caso: dos nombres y un apellido
 elif len(partes) == 3:
     primer_nombre = partes[0]
     primer_apellido = partes[1]
     segundo_apellido = partes[2]
     correo = (
        primer_nombre[0]
      + primer_apellido
      + segundo_apellido[0]
      + "@gmail.com"
 )
 # Caso: tres nombres y dos apellidos
 elif len(partes) == 4:
     primer_nombre = partes[0]
     segundo_nombre == partes[1]
     primer_apellido = partes[4]
     segundo_apellido = partes[2]
     correo = (
        primer_nombre[0]
      + primer_apellido
      + segundo_apellido[0]
      + "@gmail.com"
     )
 print("Correo generado:")
 print(correo)
except ValueError as e:
  print("Error:", e)
